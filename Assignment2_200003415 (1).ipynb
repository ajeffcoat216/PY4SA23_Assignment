# %% [markdown]
# # Lab Assignment 2 - Anastasia Jeffcoat

# %% [markdown]
# ## 200003415

# %% [markdown]
# ##### https://github.com/ajeffcoat216/PY4SA23_Assignment.git

# %% [markdown]
# ### If...else statements

# %% [markdown]
# #### Question 1
# ##### Is a number divisible by 3?

# %%
x = 873
if x%3 == 0 :
    print(str(x) + " is divisible by 3.")
else: 
    print(str(x) + " is not divisible by 3.")
    
y = 659
if y%3 == 0:
    print(str(y) + " is divisible by 3.")
else:
    print(str(y) + " is not divisible by 3.")
# Out:
# 873 is divisible by 3.
# 659 is not divisible by 3.

# %% [markdown]
# #### Question 2
# ##### Is a fruit acceptable?

# %%
fruits = ["apple", "orange", "pear", "kiwi", "strawberry"]
if 'apple' in fruits:
    print("Apple is acceptable.")
else:
    print("Apple is not acceptable.")
if 'banana' in fruits:
    print("Banana is accetable.")
else:
    print("Banana is not accetable.")
# Out:
# Apple is acceptable.
# Banana is not accetable.

# %% [markdown]
# #### Question 3
# ##### How far apart are two co-ordinates?

# %%
from haversine import haversine, Unit
#my home town to St. Andrews
#lat, long
#answer will be in km
bedworth = (52.4814, 1.4689)
standrews = (56.3398, 2.7967)
haversine(bedworth, standrews)
# Out:
# 437.5327443711939

# %% [markdown]
# ### Pandas and NumPy

# %%
import numpy as np
import pandas as pd
ppt = pd.read_csv("portland_park_trees.csv", sep=",", header=0, encoding="ISO-8859-1")

# %%
#how many data points are we working with?
print(len(ppt))
# Out:
# 25534

# %% [markdown]
# #### Question 1
# ##### How many trees are of the Quercus or Acer genus?

# %%
qanda = ppt[(ppt["Genus"]=="Quercus") + (ppt["Genus"]=="Acer")]
print(len(qanda))
# Out:
# 5675

# %% [markdown]
# #### Question 2
# ##### How many trees are of the Quercus or Acer genus, and have a DBH larger than 50 inches?

# %%
qadbh50 = ppt[(ppt["Genus"]=="Quercus") + (ppt["Genus"]=="Acer") & (ppt["DBH"]>50)]
print(len(qadbh50))
# Out:
# 124

# %% [markdown]
# #### Question 3
# ##### Which genus has the highest mean DBH of the following genera: Quercus, Acer or Fraxinus?

# %%
quercus = ppt[ppt["Genus"]=="Quercus"]
acer = ppt[ppt["Genus"]=="Acer"]
fraxinus = ppt[ppt["Genus"]=="Fraxinus"]
quercusdbhm = quercus["DBH"].mean()
acerdbhm = acer["DBH"].mean()
fraxinusdbhm = fraxinus["DBH"].mean()
if quercusdbhm > acerdbhm and quercusdbhm > fraxinusdbhm:
    print (str("The genus Quercus has the highest mean DBH."))
elif acerdbhm > quercusdbhm and fraxinusdbhm:
    print(str("The genus Acer has the highest mean DBH."))
else:
    print (str("The genus Fraxinus has the highest mean DBH."))

print(f"The Quercus DBH is: {quercusdbhm}")
print(f"The Acer DBH is: {acerdbhm}")
print(f"The Fraxinus DBH is: {fraxinusdbhm}")
# Out:
# The genus Quercus has the highest mean DBH.
# The Quercus DBH is: 23.56823839157492
# The Acer DBH is: 18.419085331846066
# The Fraxinus DBH is: 11.033609693877551

# %% [markdown]
# #### Question 4
# ##### How many different species of trees are recorded in the Acer genus?

# %%
acercount = acer["Species"].count()
acer.groupby("Species")["Genus"].count()
acerspecies = pd.DataFrame()
acerspecies["Count"] = acer.groupby("Species")['Genus'].count()
rows_count = len(acerspecies.index)
print (f"The Acer genus has {rows_count} different species.")
# Out:
# The Acer genus has 20 different species.

# %%
wc = pd.read_csv("world_cities.csv", sep=",", header=0, encoding="ISO-8859-1")
wc.columns =[column.replace(" ", "_") for column in wc.columns]
wc["pop_m"] = wc["pop"] / 1000000
del wc['pop']
wc.head()
# Out:
#                  city    country    lat    lon  capital     pop_m
# 0  'Abasan al-Jadidah  Palestine  31.31  34.34        0  0.005629
# 1  'Abasan al-Kabirah  Palestine  31.32  34.35        0  0.018999
# 2        'Abdul Hakim   Pakistan  30.55  72.11        0  0.047788
# 3  'Abdullah-as-Salam     Kuwait  29.36  47.98        0  0.021817
# 4               'Abud  Palestine  32.03  35.07        0  0.002456

# %% [markdown]
# #### Question 5
#
# In this first cell I import the .csv file and create a new column for population, in the millions. I then delete the original column for population.

# %% [markdown]
# Now I will subset the world cities according to 'A Coruna', the first city that starts with 'A', like my first name, 'Anastasia'>

# %%
acities = wc[wc['city'].str.startswith('A')]
print (acities)
# Out:
#                       city   country    lat     lon  capital     pop_m
# 127               A Coruna     Spain  43.33   -8.42        0  0.243088
# 128              A Estrada     Spain  42.70   -8.50        0  0.021997
# 129              A Laracha     Spain  43.25   -8.59        0  0.010856
# 130   A Pobra do Caraminal     Spain  42.61   -8.94        0  0.009955
# 131            A Ver-o-Mar  Portugal  41.40   -8.76        0  0.010971
# ...                    ...       ...    ...     ...      ...       ...
# 2628                 Azuma     Japan  36.34  139.24        0  0.023382
# 2629   Azuqueca de Henares     Spain  40.57   -3.27        0  0.024880
# 2630                  Azur    Israel  32.02   34.80        0  0.010224
# 2631                 Azusa       USA  34.14 -117.91        0  0.048992
# 2632         Azzano Decimo     Italy  45.89   12.72        0  0.014072
#
# [2506 rows x 6 columns]

# %% [markdown]
# Now I will create a list of the 5 most populous cities in Spain, where 'A Coruna' is located.

# %%
import numpy as np
import pandas as pd
spanishcities = wc[wc["country"]=="Spain"]
spanishcities.nlargest(5,'pop_m')
# Out:
#             city country    lat   lon  capital     pop_m
# 22032     Madrid   Spain  40.42 -3.71        1  3.146804
# 3385   Barcelona   Spain  41.40  2.17        0  1.591485
# 39931   Valencia   Spain  39.48 -0.39        0  0.803438
# 34629    Sevilla   Spain  37.40 -5.98        0  0.702516
# 42691   Zaragoza   Spain  41.65 -0.89        0  0.658186

# %% [markdown]
# ### Python Data Visualization

# %% [markdown]
# #### Graph 1.
# ##### Scatterplot for the genus 'Ulmus' according to DBH and Tree Height

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#I have uploaded portland_park_trees previously but want a new code for the data
ptrees = pd.read_csv("portland_park_trees.csv", header=0)
ulmus = ptrees[ptrees["Genus"]=="Ulmus"]
fig, axs = plt.subplots(1, 1)
sns.scatterplot(ax=axs, x="DBH", y="TreeHeight", data=ulmus)
axs.set_title("DBH vs. Tree Height", fontsize=20, color="#000000")
axs.grid(True)
plt.show(fig)

# %% [markdown]
# #### Graph 2.
# ##### Scatterplot for the genus 'Ulmus' according to DBH and 'Tree Height', coloured according to species of 'Ulmus'

# %%
fig, axs = plt.subplots(1, 1)
sns.scatterplot(ax=axs, x="DBH", y="TreeHeight", hue='Species', data=ulmus)
axs.set_title("DBH vs. Tree Height", fontsize=20, color="#000000")
handles, labels = axs.get_legend_handles_labels()
axs.grid(True)
fig.patch.set_facecolor('#adb7c7')
plt.show(fig)

# %% [markdown]
# #### Graph 3.
# ##### A series of boxplots for the genus 'Ulmus', each boxplot shows a different species.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ptrees = pd.read_csv("portland_park_trees.csv", header=0)
ulmus = ptrees[ptrees["Genus"]=="Ulmus"]
ulspdbh = sns.boxplot( x=ulmus['Species'], y=ulmus['DBH'])
ulspdbh.set_xlabel('Species', fontsize= 14, fontweight='bold')
ulspdbh.set_ylabel('DBH', fontsize= 14, fontweight='bold')
ulspdbh.set_title('Series of boxplots showing the distribution of DBH by Species of the Ulmus genus', fontsize= 18, fontweight='bold');

# %% [markdown]
# #### Graph 4.
# ##### Combining Graphs 1 and 3 into a single figure.

# %%
f, axs = plt.subplots(1,2, figsize=(10,5),sharey=True,gridspec_kw=dict(width_ratios=[10,12]))
sns.scatterplot(data= ulmus, x="TreeHeight", y="DBH", hue="Species", ax=axs[0], legend=0)
sns.boxplot(data=ulmus, x = "Species", y="DBH", ax=axs[1])
f.tight_layout()
f.patch.set_facecolor('#c8cce3')
f.legend=False

# %% [markdown]
# ### Python Geopandas

# %% [markdown]
# ##### T1.
# Read the shapefile of Tree Preservation Orders of the Perth and Kinross Council through using geopandas:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import contextily as ctx
import rasterio as rio
from rasterio import plot
plt.rcParams['figure.figsize'] = [10, 8]

TreesPKC = gpd.read_file('Tree_Preservation_Order.shp')
TreesPKC.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# This plot of the Tree Preservation Orders is unclear and confusing as to what is being shown. I will use '.explore()' to visualise better this shapefile.

# %%
TreesPKC.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6c23933532707a0afa13a0b1f03ac17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6c23933532707a0afa13a0b1f03ac17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6c23933532707a0afa13a0b1f03ac17 = L.map(
#                 &quot;map_c6c23933532707a0afa13a0b1f03ac17&quot;,
#                 {
#                     center: [56.433854117609016, -3.6185687852336583],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c6c23933532707a0afa13a0b1f03ac17);
#
#
#
#
#
#             var tile_layer_67da7a8741df70ffca9e4eaedb002625 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c6c23933532707a0afa13a0b1f03ac17);
#
#
#             map_c6c23933532707a0afa13a0b1f03ac17.fitBounds(
#                 [[56.160138990147324, -4.1746555908999845], [56.70756924507071, -3.062481979567332]],
#                 {}
#             );
#
#
#         function geo_json_99d96518737d082c6f8edbf6be1dd87a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_99d96518737d082c6f8edbf6be1dd87a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_99d96518737d082c6f8edbf6be1dd87a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_99d96518737d082c6f8edbf6be1dd87a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_99d96518737d082c6f8edbf6be1dd87a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_99d96518737d082c6f8edbf6be1dd87a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_99d96518737d082c6f8edbf6be1dd87a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_99d96518737d082c6f8edbf6be1dd87a = L.geoJson(null, {
#                 onEachFeature: geo_json_99d96518737d082c6f8edbf6be1dd87a_onEachFeature,
#
#                 style: geo_json_99d96518737d082c6f8edbf6be1dd87a_styler,
#                 pointToLayer: geo_json_99d96518737d082c6f8edbf6be1dd87a_pointToLayer
#         });
#
#         function geo_json_99d96518737d082c6f8edbf6be1dd87a_add (data) {
#             geo_json_99d96518737d082c6f8edbf6be1dd87a
#                 .addData(data)
#                 .addTo(map_c6c23933532707a0afa13a0b1f03ac17);
#         }
#             geo_json_99d96518737d082c6f8edbf6be1dd87a_add({&quot;bbox&quot;: [-4.1746555908999845, 56.160138990147324, -3.062481979567332, 56.70756924507071], &quot;features&quot;: [{&quot;bbox&quot;: [-3.697935371503087, 56.29515708689525, -3.694639512786563, 56.29670346328813], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-3.695410866723001, 56.295239167254316], [-3.695689694159139, 56.295357652351186], [-3.696669520090655, 56.295785963169074], [-3.6968796146113596, 56.29587716361126], [-3.697085044372817, 56.29596591166185], [-3.6972999196899368, 56.29605956185462], [-3.697860344180029, 56.296303745513946], [-3.697935371503087, 56.29633646670936], [-3.6974121831595235, 56.2967

# %% [markdown]
# ##### T2 & T3.
# Plot the first and final 5 sets of records from the SG_UrbanRural_2020 shapefile.
#
# Note: these data points are difficult to see on the .explore() maps, they are in bright blue but very small in size.

# %%
gpd.read_file('Tree_Preservation_Order.shp')
TreesPKC5 = TreesPKC.nlargest(5, 'MI_PRINX')
TreesPKC05 = TreesPKC.nsmallest(5, 'MI_PRINX')
TreesPKC5.explore(column='TOWN')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d394fc31d8d8087dc6d9064df71912ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend TOWN&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;TOWN&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Blairgowrie&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;Fortingall&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#f7b6d2&#x27;&gt;&lt;/span&gt;Inchture&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Perth&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d394fc31d8d8087dc6d9064df71912ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d394fc31d8d8087dc6d9064df71912ba = L.map(
#                 &quot;map_d394fc31d8d8087dc6d9064df71912ba&quot;,
#                 {
#                     center: [56.50279206902473, -3.620650806292712],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d394fc31d8d8087dc6d9064df71912ba);
#
#
#
#
#
#             var tile_layer_b0a68a4ba645e3d9a8e13e0456636853 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d394fc31d8d8087dc6d9064df71912ba);
#
#
#             map_d394fc31d8d8087dc6d9064df71912ba.fitBounds(
#                 [[56.39901941495404, -4.035505620320819], [56.60656472309542, -3.205795992264605]],
#                 {}
#             );
#
#
#         function geo_json_1a0f11eb5076d33c1163ab45f6adb341_styler(feature) {
#             switch(feature.id) {
#                 case &quot;87&quot;:
#                     return {&quot;color&quot;: &quot;#9edae5&quot;, &quot;fillColor&quot;: &quot;#9edae5&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;85&quot;:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;83&quot;:
#                     return {&quot;color&quot;: &quot;#f7b6d2&quot;, &quot;fillColor&quot;: &quot;#f7b6d2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#d62728&quot;, &quot;fillColor&quot

# %%
TreesPKC05.explore(column='TOWN')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8eabf8a7b236187c0149241b728aaa2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend TOWN&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;TOWN&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Aberfeldy&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;Abernethy&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#f7b6d2&#x27;&gt;&lt;/span&gt;Almondbank&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Auchterarder&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8eabf8a7b236187c0149241b728aaa2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8eabf8a7b236187c0149241b728aaa2 = L.map(
#                 &quot;map_a8eabf8a7b236187c0149241b728aaa2&quot;,
#                 {
#                     center: [56.4529374308879, -3.5933100638651325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a8eabf8a7b236187c0149241b728aaa2);
#
#
#
#
#
#             var tile_layer_26ab695425281fbb9df4f392555ee1e3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8eabf8a7b236187c0149241b728aaa2);
#
#
#             map_a8eabf8a7b236187c0149241b728aaa2.fitBounds(
#                 [[56.29101210894573, -3.8732271105438127], [56.61486275283007, -3.3133930171864523]],
#                 {}
#             );
#
#
#         function geo_json_8c6d02f8b0cd593c8fcdf9141f2f4088_styler(feature) {
#             switch(feature.id) {
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#d62728&quot;, &quot;fillColor&quot;: &quot;#d62728&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#f7b6d2&quot;, &quot;fillColor&quot;: &quot;#f7b6d2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#9edae5&quot;, &quot;fillColor

# %% [markdown]
# ##### T4.
# The co-ordinate system for this shapefile is:
# EPSG:27700 / British National Grid (EPSG:27700).
# This was obtained by the https://www.spatialdata.gov.scot website, but also from this code:

# %%
TreesPKC.crs
# Out:
# <Derived Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.0, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %% [markdown]
# ##### T5.
# This dataset contains 15 features, or columns, which were obtained by this code:

# %%
len(TreesPKC.columns)
# Out:
# 15

# %% [markdown]
# This dataset also has 88 data points, obtained by this code:

# %%
len(TreesPKC)
# Out:
# 88

# %% [markdown]
# ##### T6 & T8.
# Now I am creating and plotting a new geopandas dataframe to see all the trees with a preservation order in the town of Auchterarder. The legend shows the code names for each tree, coloured to show where they are around the town of Auchterarder.

# %%
Atrees = TreesPKC[TreesPKC["TOWN"]=="Auchterarder"]
Atrees.explore(column='NEW__ID', legend=True, cmap='gist_rainbow')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e27f534634c142989df060b7db514ece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend NEW__ID&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;NEW__ID&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0029&#x27;&gt;&lt;/span&gt;A10&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff9c00&#x27;&gt;&lt;/span&gt;A11&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9eff00&#x27;&gt;&lt;/span&gt;A3&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00ff27&#x27;&gt;&lt;/span&gt;A4&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00ffeb&#x27;&gt;&lt;/span&gt;A5&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#004dff&#x27;&gt;&lt;/span&gt;A7&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7900ff&#x27;&gt;&lt;/span&gt;A8&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff00bf&#x27;&gt;&lt;/span&gt;A9&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e27f534634c142989df060b7db514ece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e27f534634c142989df060b7db514ece = L.map(
#                 &quot;map_e27f534634c142989df060b7db514ece&quot;,
#                 {
#                     center: [56.2942089666185, -3.7102012418312684],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e27f534634c142989df060b7db514ece);
#
#
#
#
#
#             var tile_layer_2ec158128812fa4382c3d90451f3408c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e27f534634c142989df060b7db514ece);
#
#
#             map_e27f534634c142989df060b7db514ece.fitBounds(
#                 [[56.289176050286244, -3.729880515329966], [56.29924188295075, -3.6905219683325714]],
#                 {}
#             );
#
#
#         function geo_json_35b79f04ca9e86b8b858bbfd158eecec_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#7900ff&quot;, &quot;fillColor&quot;: &quot;#7900ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#004dff&quot;, &quot;fillColor&quot;: &q

# %% [markdown]
# ##### T7 & T8
# Now I am creating and plotting a new Geopandas dataframe using a numerical attribute - perimeter. The map below shows the trees with a preservation order that have a perimeter of more than 400cm.

# %%
Peritrees = TreesPKC[(TreesPKC["PERIMETER"]>400)]
Peritrees.explore(column='TOWN', legend=True, cmap='gist_rainbow')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc241a1c38e32883ec9139d009fc9891 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend TOWN&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;TOWN&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0029&#x27;&gt;&lt;/span&gt;Almondbank&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff3900&#x27;&gt;&lt;/span&gt;Auchterarder&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff9c00&#x27;&gt;&lt;/span&gt;Bankfoot&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fffe00&#x27;&gt;&lt;/span&gt;Blairgowrie&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9eff00&#x27;&gt;&lt;/span&gt;Bridge of Cally&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#3bff00&#x27;&gt;&lt;/span&gt;Coupar Angus&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00ff27&#x27;&gt;&lt;/span&gt;Crieff&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00ff89&#x27;&gt;&lt;/span&gt;Fortingall&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00ffeb&#x27;&gt;&lt;/span&gt;Glencarse&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#00b0ff&#x27;&gt;&lt;/span&gt;Kinross&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#004dff&#x27;&gt;&lt;/span&gt;Milnathort&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1600ff&#x27;&gt;&lt;/span&gt;Murthly&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7900ff&#x27;&gt;&lt;/span&gt;Perth&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#dc00ff&#x27;&gt;&lt;/span&gt;Pitlochry&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff00bf&#x27;&gt;&lt;/span&gt;Powmill&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc241a1c38e32883ec9139d009fc9891&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc241a1c38e32883ec9139d009fc9891 = L.map(
#                 &quot;map_bc241a1c38e32883ec9139d009fc9891&quot;,
#                 {
#                     center: [56.433854117609016, -3.646598458124005],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bc241a1c38e32883ec9139d009fc9891);
#
#
#
#
#
#             var tile_layer_0b6965503995b83c379d84e5e53d5daf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false,

# %% [markdown]
# ### Python Rasterio

# %% [markdown]
# #### T1.
# Reading the 'elev.tif' file as a Rasterio dataset, the code is below:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas
import seaborn as sns
import rasterio as rio
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

elevation = rio.open('elev.tif')

# %% [markdown]
# #### T2.
# The Co-ordinate Reference System (CRS) for this dataset is EPSG:32617, which was received by this code:

# %%
print(elevation.crs)
# Out:
# EPSG:32617

# %% [markdown]
# #### T3.
# I will now describe the dataset, using the following code. This code reveals the name, the bands, and the extent of the raster. I also discovered the number of columns and rows in this dataset, from the 'height' and 'width' codes.

# %%
print(elevation.name)
print(elevation.count)
print(elevation.width)
print(elevation.height)
print(elevation.bounds)
# Out:
# elev.tif
# 1
# 6303
# 5897
# BoundingBox(left=479753.39945587853, bottom=4170823.2037591375, right=668843.3994558785, top=4347733.203759138)

# %%
elevation.indexes
# Out:
# (1,)

# %%
from rasterio.plot import show
show(elevation, 1, title='Rasterio plot of elevation')
#I had issues with this section of the assignment, the following map was not always what appeared when the code was set
#Often there was a purple square with a blank yellow shape and green outline
#I believe it must have either taken the rasterio code a while to read the plot
#or after completing the next code (creating a FCC) allowed it to carry out this without further coding
#This is confusing however
# Out:
# <AxesSubplot: title={'center': 'Rasterio plot of elevation'}>

# %%
#googled how to create a more beige/'realistic' plotting, where you can more clearly see changes in elevations
#a false colour composite (FCC) or true colour composite (TCC)
fig, ax = plt.subplots(figsize=(6,6))
show(elevation, cmap='Blues', ax=ax, alpha=0.33)
show(elevation, cmap='Greens', ax=ax, alpha=0.33)
show(elevation, cmap="Reds", ax=ax, alpha=0.33)
plt.title("FCC Rasterio of Elevation")
plt.show()

# %% [markdown]
# #### Created a Histogram of the Rasterio file

# %%
from rasterio.plot import show_hist
fig, axhist = plt.subplots(1, 1)
show_hist(source=elevation, bins=50, facecolor='purple', histtype='stepfilled',
          lw=0.0, stacked=False, label=None, alpha=0.8, ax=axhist)
axhist.set_xlabel('Elevation (m)')
axhist.set_ylabel('Frequency')
axhist.set_title('Histogram of Elevation')
legend = plt.legend(title="Colour indicating the frequency of each bar of elevation", loc=1, prop={'size': 5})
#do not know how to change the label of purple in the legend box
#googled but to know avail
